# %%
# !pip install langchain-huggingface python-dotenv
from langchain_huggingface import ChatHuggingFace, HuggingFaceEndpoint
from dotenv import load_dotenv

# %%
import os
load_dotenv()

# Print the token to verify it's loaded (first few characters only for security)
token = os.getenv("HUGGINGFACEHUB_ACCESS_TOKEN")
if token:
    print(f"Token loaded: {token[:10]}...")
else:
    print("Token not found!")

llm = HuggingFaceEndpoint(
    repo_id="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    task="text-generation",
    huggingfacehub_api_token=token  
)

model = ChatHuggingFace(llm=llm)

result = model.invoke("What is the capital of India")

print(result)
# Out:
# Token loaded: hf_RwvQEME...
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniforge/base/envs/tf_numpy2/lib/python3.11/site-packages/huggingface_hub/utils/_http.py:409, in hf_raise_for_status(response, endpoint_name)
#     408 try:
# --> 409     response.raise_for_status()
#     410 except HTTPError as e:
#
# File /opt/homebrew/Caskroom/miniforge/base/envs/tf_numpy2/lib/python3.11/site-packages/requests/models.py:1026, in Response.raise_for_status(self)
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 503 Server Error: Service Temporarily Unavailable for url: https://router.huggingface.co/featherless-ai/v1/chat/completions
#
# The above exception was the direct cause of the following exception:
#
# HfHubHTTPError                            Traceback (most recent call last)
# ...

# %% [markdown]
# **Your `.env` setup is working perfectly!**
#
# ### What was the issue?
# - The environment variable `HUGGINGFACEHUB_ACCESS_TOKEN` is being loaded correctly
# - The `load_dotenv()` function is finding and reading your `.env` file
# - The API errors you're seeing are server-side issues, not authentication problems
#
# ### Key learnings for Jupyter notebooks with .env files:
#
# 1. **Place `.env` in the same directory** as your notebook
# 2. **Import and call `load_dotenv()`** at the start of your notebook
# 3. **Use `os.getenv()`** to access the variables
# 4. **Restart kernel** if you modify the `.env` file
#
# ### Your working setup:
# ```python
# from dotenv import load_dotenv
# import os
#
# load_dotenv()
# token = os.getenv("HUGGINGFACEHUB_ACCESS_TOKEN")
# ```
#
# The HuggingFace API is currently experiencing availability issues, but your environment setup is correct!

# %%
# Environment Variables Setup Guide

## ✅ Your .env file is working correctly!

Your environment variables are being loaded properly. The token `HUGGINGFACEHUB_ACCESS_TOKEN` is available.

## How to ensure .env files work in Jupyter notebooks:

1. **Location**: Place your `.env` file in the same directory as your notebook (✅ Done)
2. **Format**: Your `.env` file should look like:
   ```
   HUGGINGFACEHUB_ACCESS_TOKEN=hf_your_token_here
   ```
3. **Loading**: Use `load_dotenv()` at the beginning of your notebook (✅ Done)

## Common troubleshooting:

- If running from different directory, specify path: `load_dotenv('/path/to/.env')`
- Restart kernel if you change .env file
- Check current working directory matches .env location
